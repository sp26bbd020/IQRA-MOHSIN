# %%
# iqra Mohsin
#sp26_bbd_020
#practice questions.

# %%
#q1:
from datetime import datetime
def greet_with_time(name):
    current_time = datetime.now().strftime("%H:%M:%S")
    print("Hello", name)
    print("Current Time:", current_time)
greet_with_time("Iqra")
# Out:
# Hello Iqra
# Current Time: 10:20:11

# %%
#q2:
def calculate_average(a, b, c):
    average = (a + b + c) / 3
    return average

result = calculate_average(10, 20, 30)
print("Average =", result)
# Out:
# Average = 20.0

# %%
#q3:
def calculate_discount(price, discount=10):
    final_price = price - (price * discount / 100)
    return final_price
print(calculate_discount(1000))
print(calculate_discount(1000, 20))
# Out:
# 900.0
# 800.0

# %%
#q4:
def print_info(name, age, city):
    print(f"Name: {name}")
    print(f"Age: {age}")
    print(f"City: {city}")
print_info(name="Iqra", age=19, city="Faisalabad")
# Out:
# Name: Iqra
# Age: 19
# City: Faisalabad

# %%
#q5:
def find_max(*numbers):
    return max(numbers)
print(find_max(2,5,8,1,9))
# Out:
# 9

# %%
#q6:
def factorial(n):
    if n == 1:
        return 1
    else:
        return n * factorial(n - 1)
print(factorial(5))
# Out:
# 120

# %%
#q8:
def double(x):
    return x * 2
def apply_operation(func, numbers):
    new_list = []
    for num in numbers:
        new_list.append(func(num))
    return new_list
print(apply_operation(double, [1, 2, 3, 4]))
# Out:
# [2, 4, 6, 8]

# %%
#q9:
import time
def timer_decorator(func):
    def wrapper():
        start = time.time()
        func()
        end = time.time()
        print("Execution Time:", end - start)
    return wrapper
@timer_decorator
def hello():
    print("Hello World")
hello()
# Out:
# Hello World
# Execution Time: 0.00021576881408691406
